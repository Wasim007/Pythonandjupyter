# %%
import pandas as pd                 #this commands are used to import userdefined dataset into jupyter and to visualize the dataset
gdpdata=pd.read_csv("GDP.csv")
gdpdata
# Out:
#        Year Afghanistan    Angola    Albania United Arab Emirates  Argentina  \
# 0       1.0         NaN       NaN        NaN                  NaN        NaN
# 1     730.0         NaN       NaN        NaN                  NaN        NaN
# 2    1000.0         NaN       NaN        NaN                  NaN        NaN
# 3    1090.0         NaN       NaN        NaN                  NaN        NaN
# 4    1120.0         NaN       NaN        NaN                  NaN        NaN
# ..      ...         ...       ...        ...                  ...        ...
# 768  2014.0      2,022     8,673      9,808               72,601     19,183
# 769  2015.0      1,928     8,689     10,032               74,746     19,502
# 770  2016.0      1,929     8,453     10,342               75,876     18,875
# 771  2017.0      2,015     8,146     10,702               76,643     19,201
# 772  2018.0      1,935     7,771     11,104               76,398     18,556
#
# ...

# %% [markdown]
# ## (title of figure) as mention below

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(30,30)) #by this command the size of figure is increased
sns.lineplot(x="Year", y="Afghanistan" , data=gdpdata)
plt.title("Afghanistan ka GDP")
plt.show()

# %% [markdown]
# ## set styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#set_style(style="none", rc="none") # this is not working and this is assignment i will search this in internet
plt.figure(figsize=(30,30)) #by this command the size of figure is increased
sns.lineplot(x="Year", y="Afghanistan" , data=gdpdata)
sns.set_style("white")
plt.title("Afghanistan ka GDP")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MR_WAS~1\AppData\Local\Temp/ipykernel_6352/69379866.py in <module>
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 set_style(style="none", rc="none")
#       4 plt.figure(figsize=(30,30)) #by this command the size of figure is increased
#       5 sns.lineplot(x="Year", y="Afghanistan" , data=gdpdata)
#
# NameError: name 'set_style' is not defined
